# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
# your code here

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def generate_random_numbers(bottom, ceiling, count):
    return np.random.uniform(bottom, ceiling, count)

# %%
random_numbers_set1 = generate_random_numbers(10, 15, 100)

random_numbers_set2 = generate_random_numbers(10, 60, 1000)

# %%
# Plot for the first set of random numbers
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(random_numbers_set1, bins=10, edgecolor='black')
plt.title('Uniform Distribution (10, 15, 100)')


# Plot for the second set of random numbers
plt.subplot(1, 2, 2)
plt.hist(random_numbers_set2, bins=10, edgecolor='black')
plt.title('Uniform Distribution (10, 60, 1000)')

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
#The second one appears to be more uniform since its even across more samples

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.

# %%
from scipy.stats import norm 
import matplotlib.pyplot as plt
import numpy as np

# %%
mean1, std_dev1, count1 = 10, 1, 1000
normal_dist1 = norm.rvs(loc=mean1, scale=std_dev1, size=count1)

# %%
mean2, std_dev2, count2 = 10, 50, 1000
normal_dist2 = norm.rvs(loc=mean2, scale=std_dev2, size=count2)

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(normal_dist1, bins=30, edgecolor='black')
plt.title('Normal Distribution (Mean: 10, Std Dev: 1)')
plt.xlabel('Value')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
plt.hist(normal_dist2, bins=30, edgecolor='black')
plt.title('Normal Distribution (Mean: 10, Std Dev: 50)')
plt.xlabel('Value')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
# your code here

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# The two distributions are located around the same point, but the second one is more spread.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
import pandas as pd

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
vehicles = pd.read_csv('vehicles.csv')
vehicles.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# ...

# %%
def plot_column(column_name):
    plt.figure(figsize=(12, 6))

    plt.hist(vehicles[column_name], bins=30, edgecolor='black')
    plt.title(column_name)

    plt.tight_layout()
    plt.show()

plot_column('Fuel Barrels/Year')

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
plot_column('CO2 Emission Grams/Mile')

# %%
# your code here

# %% [markdown]
# 3. Combined MPG

# %%
plot_column('Combined MPG')

# %%
# your code here

# %%
# your code here

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %% [markdown]
# None of them are normally ditributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.

# %%
def generate_exponential_data(mean, size):
    return np.random.exponential(scale=mean, size=size)

data_10 = generate_exponential_data(10, 10)
data_100 = generate_exponential_data(10, 100)

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.hist(data_10, bins=100, edgecolor='black')
plt.title('Exponential Distribution (size=10)')

plt.subplot(1, 2, 2)
plt.hist(data_100, bins=100, edgecolor='black')
plt.title('Exponential Distribution (size=100)')

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
mean_time = 10
lambda_param = 1 / mean_time  

prob_less_15 = 1 - np.exp(-(1 / mean_time ) * 15)
print("Probability that a customer will spend less than 15 minutes in the bank: ", prob_less_15)
# Out:
# Probability that a customer will spend less than 15 minutes in the bank:  0.7768698398515702

# %%
# your answer here
# Hint: This is same as saying P(x<15)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
prob_more_15 = np.exp(-(1 / mean_time ) * 15)
print("Probability that a customer will spend more than 15 minutes in the bank: ", prob_more_15)
# Out:
# Probability that a customer will spend more than 15 minutes in the bank:  0.22313016014842982
